# %%
# Import the dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates= list(lat_lngs)
print (coordinates)
# Out:
# [(-7.733053651799665, -84.83268480367013), (17.831542809758247, 100.75484592414972), (-6.363405761145742, -111.30628253579562), (-50.43166032939669, 29.097418259464007), (84.85965489593795, 12.635394683044979), (-29.842266530117193, -3.199388186648207), (-6.814775582934288, -15.920600931678848), (1.9759714927805305, 152.89311879450804), (2.3134887605674237, 107.68109327093839), (-45.79246515256018, 46.67830651273016), (71.78153738954646, 59.649596825938346), (-28.50181484970372, 82.15643860158997), (-11.54720898762379, -16.655788744979162), (33.440414025377024, 23.75199071235039), (30.28436722739157, -125.1886162072863), (-67.39722558473018, 24.332226473622512), (78.81049903250167, -32.60598549920522), (-86.15512572302242, -160.43471675535957), (-26.821366703172117, -40.22534912615231), (-4.565173006429134, -100.05504076150166), (61.740422299874496, 25.10944924714059), (-38.64363641770537, -124.03475882611373), (5.152204237797477, -163.68226629243972), (51.57401293650696, 10.932994377023249), (-36.270939357370914, -131.57515269953305), (47.384674801902094, -110.84931346536017), (-12.996232488392863, -112.44489248031344), (84.12741900131368, -62.805967792885724), (-37.011719002383174, -151.55606621819035), (46.030681537621064, 15.387975226015016), (-79.49997193637864, 175.95467529136255), (-25.47428020904684, 132.5144906082), (80.1048220128886, -59.54943575388644), (29.10639933436393, 156.8166080454203), (-33.19901590174491, -78.76517292366304), (81.08296124468805, -178.7188561164455), (4.843396552549109, -87.25805399599294), (-57.563813039860385, -148.46804242000934), (-55.60273216829125, 111.01515662802655), (-88.60062518344931, 109.55431578595318), (-58.771466467075534, 83.61538594159072), (67.35313333722942, 157.69885812680263), (-79.58604573954453, 110.33499728257806), (59.335694938394, 63.51573277297558), (73.39146259814547, 144.6158568706727), (-83.59564083398529, 37.166054977503705), (37.27223759795832, -81.5300048920139), (-84.31917776117571, -132.3984574599861), (51.12130840602538, -56.85229661214579), (-83.55759999910563, 3.5872255655039), (9.729689063446045, 166.09975089848575), (-73.66971632245512, -38.66187000132007), (-72.1445634055903, 33.756052018753024), (-55.34002946869078, -168.25440175946164), (-29.79907330086747, 174.01359289818026), (-68.81778007062721, 170.79176532491886), (-1.6538036386939297, 83.71775657532646), (-19.061987874167798, -143.65220348391944), (70.16754803438087, 9.087103556742562), (-20.350016565377075, 108.29624113727431), (61.74600320951842, 132.2415394385576), (11.303762048647911, -140.68422362766796), (64.86745156035991, 123.53117621626228), (-52.38944296383292, 77.5524081246212), (-20.514207555806124, 3.5027311870458675), (20.551837899769524, -164.41707294500054), (63.338323883522804, -87.50891218735316), (-42.581080614887064, 151.65477185107028), (-35.56901018673878, -145.4082932143653), (-22.630504217820587, 171.12151414497288), (26.092073217575077, -91.54464708486694), (27.733638933399064, 90.8492821466437), (4.35969148811283, 162.9064385595296), (-83.41109555085431, 38.27591602231618), (-40.990205866448854, 148.00670222938692), (46.49217916467941, -120.94996685027223), (-8.989544645628058, 164.01438891221267), (24.178336675942944, 116.61570586174389), (1.6441219064934387, 90.37742252342974), (-79.53928733177692, 145.73925267499783), (-54.76894146998529, -58.61467930894291), (-13.218804049109039, -92.12383123315439), (22.11966971775749, -46.52143472073678), (-55.46337519059979, 154.25738055560146), (81.08200519721072, -82.42613794704029), (69.20735541587655, -116.68093920054571), (-13.028212513483922, -83.8215991376652), (-59.216178707802825, -125.20496419227635), (40.70871928630743, -49.94806567155001), (7.469564354082877, -41.33288185710981), (-9.639459333706142, 122.04089328971276), (43.43713851027849, 41.436927538760955), (88.14188140306226, 122.73322468741554), (-42.50191317562939, -27.955701614795146), (-65.74036405483544, 167.21547877994112), (25.23830687168578, 40.932547334 ...

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Build the basic URL for the OpenWeatherMap with my weather_api_key added to the URL# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sechura
# Processing Record 2 of Set 1 | rong kwang
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | port elizabeth
# Processing Record 5 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | kavieng
# Processing Record 9 of Set 1 | pemangkat
# Processing Record 10 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | darnah
# Processing Record 14 of Set 1 | lompoc
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | jamsa
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | nordhausen
# Processing Record 23 of Set 1 | great falls
# Processing Record 24 of Set 1 | narsaq
# Processing Record 25 of Set 1 | sevnica
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | yulara
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | hasaki
# Processing Record 30 of Set 1 | talcahuano
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | burica
# City not found. Skipping...
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | cherskiy
# Processing Record 36 of Set 1 | gari
# Processing Record 37 of Set 1 | chokurdakh
# Processing Record 38 of Set 1 | bluefield
# Processing Record 39 of Set 1 | saint anthony
# Processing Record 40 of Set 1 | hermanus
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | vaini
# Processing Record 44 of Set 1 | kaeo
# Processing Record 45 of Set 1 | hambantota
# Processing Record 46 of Set 1 | tautira
# Processing Record 47 of Set 1 | sorland
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | churapcha
# Processing Record 50 of Set 1 | kysyl-syr
# Processing Record 1 of Set 2 | mahebourg
# Processing Record 2 of Set 2 | namibe
# Processing Record 3 of Set 2 | kapaa
# Processing Record 4 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | tadine
# Processing Record 7 of Set 2 | houma
# Processing Record 8 of Set 2 | jakar
# Processing Record 9 of Set 2 | launceston
# Processing Record 10 of Set 2 | yakima
# Processing Record 11 of Set 2 | lata
# Processing Record 12 of Set 2 | chaozhou
# Processing Record 13 of Set 2 | meulaboh
# Processing Record 14 of Set 2 | san cristobal
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | yellowknife
# Processing Record 18 of Set 2 | huarmey
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | carutapera
# Processing Record 21 of Set 2 | ende
# Processing Record 22 of Set 2 | teberda
# Processing Record 23 of Set 2 | tiksi
# Processing Record 24 of Set 2 | buraydah
# Processing Record 25 of Set 2 | itaituba
# Processing Record 26 of Set 2 | faanui
# Processing Record 27 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 2 | roma
# Processing Record 29 of Set 2 | gat
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | nemuro
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | whitehorse
# Processing Record 35 of Set 2 | garissa
# Processing Record 36 of Set 2 | makakilo city
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 2 | punta arenas
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | vila franca do campo
# Processing Record 42 of Set 2 | marv dasht
# City not found. Skipping...
# Processing Record 43 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | dikson
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | nanortalik
# Processing Record 48 of Set 2 | suzu
# City not found. Skipping...
# Processing Record 49 of Set 2 | tuktoyaktuk
# Processing Record 50 of Set 2 | east london
# Processing Record 1 of Set 3 | mount isa
# Processing Record 2 of Set 3 | harper
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | palencia
# Processing Record 5 of Set 3 | balkhash
# Processing Record 6 of Set 3 | uvira
# Processing Record 7 of Set 3 | menzelinsk
# Processing Record 8 of Set 3 | inirida
# Processing Record 9 of Set 3 | sola
# Processing Record 10 of Set 3 | veraval
# Processing Record 11 of Set 3 | geraldton
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | constitucion
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | mitu
# Processing Record 16 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 3 | enshi
# Processing Record 18 of Set 3 | roebourne
# Processing Record 19 of Set 3 | san fernando
# Processing Record 20 of Set 3 | dunedin
# Processing Record 21 of Set 3 | puerto penasco
# Processing Record 22 of Set 3 | korla
# Processing Record 23 of Set 3 | vrede
# Processing Record 24 of Set 3 | mahibadhoo
# Processing Record 25 of Set 3 | faya
# Processing Record 26 of Set 3 | ostrovnoy
# Processing Record 27 of Set 3 | talnakh
# Processing Record 28 of Set 3 | mujiayingzi
# Processing Record 29 of Set 3 | svay rieng
# Processing Record 30 of Set 3 | ola
# Processing Record 31 of Set 3 | nieuw amsterdam
# Processing Record 32 of Set 3 | alofi
# Processing Record 33 of Set 3 | kampot
# Processing Record 34 of Set 3 | seoul
# Processing Record 35 of Set 3 | sao filipe
# Processing Record 36 of Set 3 | strezhevoy
# Processing Record 37 of Set 3 | shadegan
# Processing Record 38 of Set 3 | college
# Processing Record 39 of Set 3 | klyuchi
# Processing Record 40 of Set 3 | luzhou
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | pirgos
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | half moon bay
# Processing Record 45 of Set 3 | mount gambier
# Processing Record 46 of Set 3 | coihaique
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | broken hill
# Processing Record 49 of Set 3 | coquimbo
# Processing Record 50 of Set 3 | yumaguzino
# Processing Record 1 of Set 4 | saskylakh
# Processing Record 2 of Set 4 | kayes
# Processing Record 3 of Set 4 | taltal
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | atuona
# Processing Record 6 of Set 4 | saint-tite
# Processing Record 7 of Set 4 | aktash
# Processing Record 8 of Set 4 | enid
# Processing Record 9 of Set 4 | ust-nera
# Processing Record 10 of Set 4 | shingu
# Processing Record 11 of Set 4 | breves
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | indiaroba
# Processing Record 15 of Set 4 | ystad
# Processing Record 16 of Set 4 | tpig
# Processing Record 17 of Set 4 | matanzas
# Processing Record 18 of Set 4 | jaguariaiva
# Processing Record 19 of Set 4 | vardo
# Processing Record 20 of Set 4 | noumea
# Processing Record 21 of Set 4 | victoria
# Processing Record 22 of Set 4 | narasapur
# Processing Record 23 of Set 4 | barstow
# Processing Record 24 of Set 4 | kismayo
# Processing Record 25 of Set 4 | blonduos
# City not found. Skipping...
# Processing Record 26 of Set 4 | thanh hoa
# Processing Record 27 of Set 4 | nabire
# Processing Record 28 of Set 4 | maine-soroa
# Processing Record 29 of Set 4 | beisfjord
# Processing Record 30 of Set 4 | hit
# Processing Record 31 of Set 4 | saint-augustin
# Processing Record 32 of Set 4 | lebu
# Processing Record 33 of Set 4 | sidi ali
# Processing Record 34 of Set 4 | opelousas
# Processing Record 35 of Set 4 | saint george
# Processing Record 36 of Set 4 | kenai
# Processing Record 37 of Set 4 | correntina
# Processing Record 38 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 39 of Set 4 | dalbandin
# Processing Record 40 of Set 4 | bulawayo
# Processing Record 41 of Set 4 | kruisfontein
# Processing Record 42 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 4 | san andres
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | amapa
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | jiazi
# Processing Record 48 of Set 4 | castro
# Processing Record 49 of Set 4 | sur
# Processing Record 50 of Set 4 | ribeira grande
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | saint-philippe
# Processing Record 3 of Set 5 | lokosovo
# Processing Record 4 of Set 5 | lagoa
# Processing Record 5 of Set 5 | kavaratti
# Processing Record 6 of Set 5 | barranca
# Processing Record 7 of Set 5 | esperance
# Processing Record 8 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 5 | asyut
# Processing Record 10 of Set 5 | ylivieska
# Processing Record 11 of Set 5 | razole
# Processing Record 12 of Set 5 | barrow
# Processing Record 13 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 5 | pochutla
# Processing Record 15 of Set 5 | kahului
# Processing Record 16 of Set 5 | finkenstein
# Processing Record 17 of Set 5 | padang
# Processing Record 18 of Set 5 | matara
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | general pico
# Processing Record 22 of Set 5 | calvia
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | lodwar
# Processing Record 25 of Set 5 | khatanga
# Processing Record 26 of Set 5 | waipawa
# Processing Record 27 of Set 5 | zanjan
# Processing Record 28 of Set 5 | black river
# Processing Record 29 of Set 5 | new norfolk
# Processing Record 30 of Set 5 | erdenet
# Processing Record 31 of Set 5 | grand gaube
# Processing Record 32 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 5 | te anau
# Processing Record 34 of Set 5 | yeniseysk
# Processing Record 35 of Set 5 | morant bay
# Processing Record 36 of Set 5 | havoysund
# Processing Record 37 of Set 5 | avarua
# Processing Record 38 of Set 5 | okhotsk
# Processing Record 39 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 5 | trapani
# Processing Record 41 of Set 5 | ucluelet
# Processing Record 42 of Set 5 | elko
# Processing Record 43 of Set 5 | ngama
# Processing Record 44 of Set 5 | moerai
# Processing Record 45 of Set 5 | petlawad
# Processing Record 46 of Set 5 | kharhial
# Processing Record 47 of Set 5 | pingshan
# Processing Record 48 of Set 5 | karpathos
# Processing Record 49 of Set 5 | surab
# Processing Record 50 of Set 5 | codrington
# Processing Record 1 of Set 6 | krasnokamensk
# Processing Record 2 of Set 6 | bethanien
# Processing Record 3 of Set 6 | ghanzi
# Processing Record 4 of Set 6 | hammerfest
# Processing Record 5 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 6 of Set 6 | olinda
# Processing Record 7 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 6 | ribeira brava
# Processing Record 9 of Set 6 | sao gabriel da cachoeira
# Processing Record 10 of Set 6 | baijiantan
# Processing Record 11 of Set 6 | kefamenanu
# Processing Record 12 of Set 6 | iquique
# Processing Record 13 of Set 6 | north bend
# Processing Record 14 of Set 6 | tyrma
# Processing Record 15 of Set 6 | zoniana
# Processing Record 16 of Set 6 | aleksandrov gay
# Processing Record 17 of Set 6 | carlagan
# Processing Record 18 of Set 6 | westport
# Processing Record 19 of Set 6 | moen
# Processing Record 20 of Set 6 | itarema
# Processing Record 21 of Set 6 | caraballeda
# Processing Record 22 of Set 6 | toora-khem
# Processing Record 23 of Set 6 | umea
# Processing Record 24 of Set 6 | jian
# Processing Record 25 of Set 6 | port keats
# Processing Record 26 of Set 6 | tank
# Processing Record 27 of Set 6 | hobyo
# Processing Record 28 of Set 6 | markala
# Processing Record 29 of Set 6 | pangnirtung
# Processing Record 30 of Set 6 | port hardy
# Processing Record 31 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | nanzhang
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | mchinji
# Processing Record 36 of Set 6 | porto velho
# Processing Record 37 of Set 6 | bethel
# Processing Record 38 of Set 6 | oistins
# Processing Record 39 of Set 6 | sao joao da barra
# Processing Record 40 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 6 | paka
# Processing Record 42 of Set 6 | volchikha
# Processing Record 43 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 6 | salta
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | tlacotepec
# Processing Record 47 of Set 6 | yanchukan
# City not found. Skipping...
# Processing Record 48 of Set 6 | priargunsk
# Processing Record 49 of Set 6 | ocos
# Processing Record 50 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 7 | omsukchan
# Processing Record 2 of Set 7 | kamariotissa
# Processing Record 3 of Set 7 | vanimo
# Processing Record 4 of Set 7 | vao
# Processing Record 5 of Set 7 | tezu
# Processing Record 6 of Set 7 | skjervoy
# Processing Record 7 of Set 7 | antalaha
# Processing Record 8 of Set 7 | bilma
# Processing Record 9 of Set 7 | ponta delgada
# Processing Record 10 of Set 7 | bonfim
# Processing Record 11 of Set 7 | kang
# Processing Record 12 of Set 7 | beloha
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | biak
# Processing Record 15 of Set 7 | altamont
# Processing Record 16 of Set 7 | vershino-darasunskiy
# Processing Record 17 of Set 7 | iquitos
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | kirksville
# Processing Record 20 of Set 7 | villa carlos paz
# Processing Record 21 of Set 7 | ibra
# Processing Record 22 of Set 7 | ilam
# Processing Record 23 of Set 7 | ferme-neuve
# Processing Record 24 of Set 7 | prince george
# Processing Record 25 of Set 7 | wanning
# Processing Record 26 of Set 7 | moron
# Processing Record 27 of Set 7 | julana
# City not found. Skipping...
# Processing Record 28 of Set 7 | kawhia
# Processing Record 29 of Set 7 | pisco
# Processing Record 30 of Set 7 | santa rosa
# Processing Record 31 of Set 7 | garowe
# Processing Record 32 of Set 7 | champerico
# Processing Record 33 of Set 7 | stromness
# Processing Record 34 of Set 7 | trinidad
# Processing Record 35 of Set 7 | rockport
# Processing Record 36 of Set 7 | bangkal
# Processing Record 37 of Set 7 | atakpame
# Processing Record 38 of Set 7 | el dorado
# Processing Record 39 of Set 7 | altay
# Processing Record 40 of Set 7 | san jeronimo
# Processing Record 41 of Set 7 | ulaanbaatar
# Processing Record 42 of Set 7 | sayyan
# Processing Record 43 of Set 7 | yumen
# Processing Record 44 of Set 7 | cazones
# Processing Record 45 of Set 7 | nhulunbuy
# Processing Record 46 of Set 7 | presidencia roque saenz pena
# Processing Record 47 of Set 7 | san ignacio
# Processing Record 48 of Set 7 | puerto vallarta
# Processing Record 49 of Set 7 | umm lajj
# Processing Record 50 of Set 7 | lethem
# Processing Record 1 of Set 8 | cileunyi
# Processing Record 2 of Set 8 | ferrenafe
# Processing Record 3 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 8 | hadishahr
# Processing Record 5 of Set 8 | la palma
# Processing Record 6 of Set 8 | chimore
# Processing Record 7 of Set 8 | uray
# Processing Record 8 of Set 8 | kargasok
# Processing Record 9 of Set 8 | bani walid
# Processing Record 10 of Set 8 | chute-aux-outardes
# Processing Record 11 of Set 8 | provideniya
# Processing Record 12 of Set 8 | saint-georges
# Processing Record 13 of Set 8 | sabha
# Processing Record 14 of Set 8 | jatiroto
# Processing Record 15 of Set 8 | young
# Processing Record 16 of Set 8 | dole
# Processing Record 17 of Set 8 | opuwo
# Processing Record 18 of Set 8 | dawlatabad
# Processing Record 19 of Set 8 | kemijarvi
# Processing Record 20 of Set 8 | coahuayana
# Processing Record 21 of Set 8 | raga
# Processing Record 22 of Set 8 | mandalgovi
# Processing Record 23 of Set 8 | invercargill
# Processing Record 24 of Set 8 | sadao
# Processing Record 25 of Set 8 | peresichna
# Processing Record 26 of Set 8 | haizhou
# Processing Record 27 of Set 8 | vila velha
# Processing Record 28 of Set 8 | bitung
# Processing Record 29 of Set 8 | kamaishi
# Processing Record 30 of Set 8 | camopi
# Processing Record 31 of Set 8 | winnemucca
# Processing Record 32 of Set 8 | grande-riviere
# City not found. Skipping...
# Processing Record 33 of Set 8 | clyde river
# Processing Record 34 of Set 8 | tessalit
# Processing Record 35 of Set 8 | yerbogachen
# Processing Record 36 of Set 8 | pevek
# Processing Record 37 of Set 8 | geneva
# Processing Record 38 of Set 8 | araouane
# Processing Record 39 of Set 8 | henties bay
# Processing Record 40 of Set 8 | matagami
# Processing Record 41 of Set 8 | almaznyy
# Processing Record 42 of Set 8 | banjarmasin
# Processing Record 43 of Set 8 | caconda
# Processing Record 44 of Set 8 | camacha
# Processing Record 45 of Set 8 | severodvinsk
# Processing Record 46 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 8 | indramayu
# Processing Record 48 of Set 8 | nome
# Processing Record 49 of Set 8 | vetlanda
# Processing Record 50 of Set 8 | borovichi
# Processing Record 1 of Set 9 | novobirilyussy
# Processing Record 2 of Set 9 | hami
# Processing Record 3 of Set 9 | kidodi
# Processing Record 4 of Set 9 | isangel
# Processing Record 5 of Set 9 | sebeta
# Processing Record 6 of Set 9 | neverkino
# Processing Record 7 of Set 9 | praia
# Processing Record 8 of Set 9 | kropotkin
# Processing Record 9 of Set 9 | shelburne
# Processing Record 10 of Set 9 | cayenne
# Processing Record 11 of Set 9 | chuy
# Processing Record 12 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 9 | pitimbu
# Processing Record 14 of Set 9 | iranshahr
# Processing Record 15 of Set 9 | port blair
# Processing Record 16 of Set 9 | armeria
# Processing Record 17 of Set 9 | karonga
# Processing Record 18 of Set 9 | nioro
# Processing Record 19 of Set 9 | vestmanna
# Processing Record 20 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 9 | lesnoye
# Processing Record 22 of Set 9 | concepcion del oro
# Processing Record 23 of Set 9 | villefranche-sur-saone
# Processing Record 24 of Set 9 | phan thiet
# Processing Record 25 of Set 9 | kendari
# Processing Record 26 of Set 9 | hvide sande
# Processing Record 27 of Set 9 | dargaville
# Processing Record 28 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 29 of Set 9 | uige
# Processing Record 30 of Set 9 | roanne
# Processing Record 31 of Set 9 | amurzet
# Processing Record 32 of Set 9 | bolobo
# Processing Record 33 of Set 9 | dandong
# Processing Record 34 of Set 9 | salalah
# Processing Record 35 of Set 9 | berga
# Processing Record 36 of Set 9 | gorontalo
# Processing Record 37 of Set 9 | togur
# Processing Record 38 of Set 9 | fortuna
# Processing Record 39 of Set 9 | sahrak
# City not found. Skipping...
# Processing Record 40 of Set 9 | anapskaya
# Processing Record 41 of Set 9 | santa cruz
# Processing Record 42 of Set 9 | corner brook
# Processing Record 43 of Set 9 | haileybury
# Processing Record 44 of Set 9 | kumluca
# Processing Record 45 of Set 9 | santa maria da vitoria
# Processing Record 46 of Set 9 | pundaguitan
# Processing Record 47 of Set 9 | ulaangom
# Processing Record 48 of Set 9 | aklavik
# Processing Record 49 of Set 9 | cabedelo
# Processing Record 50 of Set 9 | pokhara
# Processing Record 1 of Set 10 | sacramento
# Processing Record 2 of Set 10 | nsoko
# Processing Record 3 of Set 10 | pingxiang
# Processing Record 4 of Set 10 | los llanos de aridane
# Processing Record 5 of Set 10 | basco
# Processing Record 6 of Set 10 | miandrivazo
# Processing Record 7 of Set 10 | cidreira
# Processing Record 8 of Set 10 | leninskoye
# Processing Record 9 of Set 10 | iacu
# Processing Record 10 of Set 10 | anahuac
# Processing Record 11 of Set 10 | emerald
# Processing Record 12 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 13 of Set 10 | labuhan
# Processing Record 14 of Set 10 | northam
# Processing Record 15 of Set 10 | srednekolymsk
# Processing Record 16 of Set 10 | entre rios
# Processing Record 17 of Set 10 | lisakovsk
# Processing Record 18 of Set 10 | sao miguel do araguaia
# Processing Record 19 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 20 of Set 10 | fairbanks
# Processing Record 21 of Set 10 | kavali
# Processing Record 22 of Set 10 | nicoya
# Processing Record 23 of Set 10 | gawler
# Processing Record 24 of Set 10 | taoudenni
# Processing Record 25 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 10 | poli
# Processing Record 27 of Set 10 | harer
# Processing Record 28 of Set 10 | bossier city
# Processing Record 29 of Set 10 | cockburn town
# Processing Record 30 of Set 10 | katangli
# Processing Record 31 of Set 10 | sokoni
# Processing Record 32 of Set 10 | muros
# Processing Record 33 of Set 10 | scicli
# Processing Record 34 of Set 10 | port-gentil
# Processing Record 35 of Set 10 | lityn
# Processing Record 36 of Set 10 | glendive
# Processing Record 37 of Set 10 | shuyskoye
# Processing Record 38 of Set 10 | poum
# Processing Record 39 of Set 10 | oranjemund
# Processing Record 40 of Set 10 | nsunga
# Processing Record 41 of Set 10 | carbonia
# Processing Record 42 of Set 10 | alyangula
# Processing Record 43 of Set 10 | richards bay
# Processing Record 44 of Set 10 | kandi
# Processing Record 45 of Set 10 | avera
# Processing Record 46 of Set 10 | santa vitoria do palmar
# Processing Record 47 of Set 10 | pilar
# Processing Record 48 of Set 10 | vestmannaeyjar
# Processing Record 49 of Set 10 | minggang
# Processing Record 50 of Set 10 | khasan
# Processing Record 1 of Set 11 | celestun
# Processing Record 2 of Set 11 | vacha
# Processing Record 3 of Set 11 | karasjok
# Processing Record 4 of Set 11 | burnie
# Processing Record 5 of Set 11 | elizabeth city
# Processing Record 6 of Set 11 | pangoa
# Processing Record 7 of Set 11 | flagstaff
# Processing Record 8 of Set 11 | upata
# Processing Record 9 of Set 11 | flinders
# Processing Record 10 of Set 11 | bushehr
# Processing Record 11 of Set 11 | neyshabur
# Processing Record 12 of Set 11 | mananjary
# Processing Record 13 of Set 11 | anadyr
# Processing Record 14 of Set 11 | pizarro
# Processing Record 15 of Set 11 | logon
# Processing Record 16 of Set 11 | morehead
# Processing Record 17 of Set 11 | sobolevo
# Processing Record 18 of Set 11 | sandavagur
# City not found. Skipping...
# Processing Record 19 of Set 11 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | ust-tarka
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | talaya
# Processing Record 23 of Set 11 | kabare
# Processing Record 24 of Set 11 | virden
# Processing Record 25 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 11 | luanda
# Processing Record 27 of Set 11 | santa margherita ligure
# Processing Record 28 of Set 11 | najran
# Processing Record 29 of Set 11 | aras
# Processing Record 30 of Set 11 | udachnyy
# Processing Record 31 of Set 11 | aksum
# Processing Record 32 of Set 11 | namatanai
# Processing Record 33 of Set 11 | kieta
# Processing Record 34 of Set 11 | portel
# Processing Record 35 of Set 11 | sompeta
# Processing Record 36 of Set 11 | alice springs
# Processing Record 37 of Set 11 | kodinsk
# Processing Record 38 of Set 11 | souillac
# Processing Record 39 of Set 11 | nambour
# Processing Record 40 of Set 11 | tura
# Processing Record 41 of Set 11 | nenjiang
# Processing Record 42 of Set 11 | la ronge
# Processing Record 43 of Set 11 | pauini
# Processing Record 44 of Set 11 | soe
# Processing Record 45 of Set 11 | kaele
# Processing Record 46 of Set 11 | dongsheng
# Processing Record 47 of Set 11 | aksu
# Processing Record 48 of Set 11 | fukue
# Processing Record 49 of Set 11 | iqaluit
# Processing Record 50 of Set 11 | high level
# Processing Record 1 of Set 12 | muncar
# Processing Record 2 of Set 12 | naze
# Processing Record 3 of Set 12 | corinto
# Processing Record 4 of Set 12 | mayya
# Processing Record 5 of Set 12 | hatta
# Processing Record 6 of Set 12 | lorengau
# Processing Record 7 of Set 12 | pangkalanbuun
# Processing Record 8 of Set 12 | zhangjiakou
# Processing Record 9 of Set 12 | gambela
# Processing Record 10 of Set 12 | shelopugino
# Processing Record 11 of Set 12 | honiara
# Processing Record 12 of Set 12 | akdepe
# Processing Record 13 of Set 12 | coronado
# Processing Record 14 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 12 | oktyabrskoye
# Processing Record 16 of Set 12 | cananeia
# Processing Record 17 of Set 12 | cheney
# Processing Record 18 of Set 12 | malakal
# Processing Record 19 of Set 12 | malmyzh
# Processing Record 20 of Set 12 | peniche
# Processing Record 21 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 12 | leh
# Processing Record 23 of Set 12 | venado tuerto
# Processing Record 24 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 12 | rudbar
# Processing Record 26 of Set 12 | son la
# Processing Record 27 of Set 12 | evensk
# Processing Record 28 of Set 12 | shizuishan
# Processing Record 29 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 30 of Set 12 | sambava
# Processing Record 31 of Set 12 | abong mbang
# Processing Record 32 of Set 12 | pangai
# Processing Record 33 of Set 12 | kasongo-lunda
# Processing Record 34 of Set 12 | sexsmith
# Processing Record 35 of Set 12 | riyadh
# Processing Record 36 of Set 12 | ouallam
# Processing Record 37 of Set 12 | north platte
# Processing Record 38 of Set 12 | port macquarie
# Processing Record 39 of Set 12 | ambon
# Processing Record 40 of Set 12 | maceio
# Processing Record 41 of Set 12 | pinega
# Processing Record 42 of Set 12 | keffi
# Processing Record 43 of Set 12 | mayumba
# Processing Record 44 of Set 12 | washington
# Processing Record 45 of Set 12 | norrtalje
# Processing Record 46 of Set 12 | flin flon
# Processing Record 47 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 48 of Set 12 | ratnagiri
# Processing Record 49 of Set 12 | bonavista
# Processing Record 50 of Set 12 | pedernales
# Processing Record 1 of Set 13 | marfino
# Processing Record 2 of Set 13 | tabasalu
# Processing Record 3 of Set 13 | batagay
# Processing Record 4 of Set 13 | izhma
# Processing Record 5 of Set 13 | shkotovo-22
# City not found. Skipping...
# Processing Record 6 of Set 13 | oxbow
# Processing Record 7 of Set 13 | aswan
# Processing Record 8 of Set 13 | guna
# Processing Record 9 of Set 13 | vestbygda
# City not found. Skipping...
# Processing Record 10 of Set 13 | barinas
# Processing Record 11 of Set 13 | agadez
# Processing Record 12 of Set 13 | kasama
# Processing Record 13 of Set 13 | yenagoa
# Processing Record 14 of Set 13 | beringovskiy
# Processing Record 15 of Set 13 | sedhiou
# Processing Record 16 of Set 13 | sumbe
# Processing Record 17 of Set 13 | novyy urengoy
# Processing Record 18 of Set 13 | encarnacion
# Processing Record 19 of Set 13 | bardiyah
# Processing Record 20 of Set 13 | ati
# Processing Record 21 of Set 13 | waingapu
# Processing Record 22 of Set 13 | kjellerup
# Processing Record 23 of Set 13 | hereford
# Processing Record 24 of Set 13 | louisville
# Processing Record 25 of Set 13 | kangaatsiaq
# Processing Record 26 of Set 13 | leningradskiy
# Processing Record 27 of Set 13 | grootfontein
# Processing Record 28 of Set 13 | hanstholm
# Processing Record 29 of Set 13 | engenheiro beltrao
# Processing Record 30 of Set 13 | yacuiba
# Processing Record 31 of Set 13 | trujillo
# Processing Record 32 of Set 13 | buala
# Processing Record 33 of Set 13 | komsomolskiy
# Processing Record 34 of Set 13 | tabou
# Processing Record 35 of Set 13 | zhigansk
# Processing Record 36 of Set 13 | husavik
# Processing Record 37 of Set 13 | prince rupert
# Processing Record 38 of Set 13 | payakumbuh
# Processing Record 39 of Set 13 | srandakan
# Processing Record 40 of Set 13 | graaff-reinet
# Processing Record 41 of Set 13 | kanniyakumari
# Processing Record 42 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 13 | ancud
# Processing Record 44 of Set 13 | san luis
# Processing Record 45 of Set 13 | bireun
# Processing Record 46 of Set 13 | corum
# Processing Record 47 of Set 13 | acajutla
# Processing Record 48 of Set 13 | ayni
# Processing Record 49 of Set 13 | wilmington island
# Processing Record 50 of Set 13 | escanaba
# Processing Record 1 of Set 14 | gannan
# Processing Record 2 of Set 14 | bandarbeyla
# Processing Record 3 of Set 14 | atar
# Processing Record 4 of Set 14 | nouakchott
# Processing Record 5 of Set 14 | elmira
# Processing Record 6 of Set 14 | beira
# Processing Record 7 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 9 of Set 14 | tual
# Processing Record 10 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 14 | katsuura
# Processing Record 12 of Set 14 | havre-saint-pierre
# Processing Record 13 of Set 14 | nago
# Processing Record 14 of Set 14 | boca do acre
# Processing Record 15 of Set 14 | ketchikan
# Processing Record 16 of Set 14 | chicama
# Processing Record 17 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 14 | darhan
# Processing Record 19 of Set 14 | byron bay
# Processing Record 20 of Set 14 | jesus carranza
# Processing Record 21 of Set 14 | salina
# Processing Record 22 of Set 14 | fenoarivo atsinanana
# Processing Record 23 of Set 14 | harrison
# Processing Record 24 of Set 14 | andenes
# Processing Record 25 of Set 14 | caravelas
# Processing Record 26 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 27 of Set 14 | soma
# Processing Record 28 of Set 14 | ourossogui
# Processing Record 29 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 30 of Set 14 | beboto
# Processing Record 31 of Set 14 | novovarshavka
# Processing Record 32 of Set 14 | saint-joseph
# Processing Record 33 of Set 14 | bestobe
# Processing Record 34 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 14 | tomatlan
# Processing Record 36 of Set 14 | khandyga
# Processing Record 37 of Set 14 | kiknur
# Processing Record 38 of Set 14 | knysna
# Processing Record 39 of Set 14 | ayan
# Processing Record 40 of Set 14 | manokwari
# Processing Record 41 of Set 14 | krasnoselkup
# Processing Record 42 of Set 14 | bama
# Processing Record 43 of Set 14 | saint cloud
# Processing Record 44 of Set 14 | kloulklubed
# Processing Record 45 of Set 14 | vrangel
# Processing Record 46 of Set 14 | erzurum
# Processing Record 47 of Set 14 | safaga
# Processing Record 48 of Set 14 | san carlos de bariloche
# Processing Record 49 of Set 14 | klaksvik
# Processing Record 50 of Set 14 | eyl
# Processing Record 1 of Set 15 | mazyr
# Processing Record 2 of Set 15 | esso
# Processing Record 3 of Set 15 | mastic beach
# Processing Record 4 of Set 15 | uzunovo
# Processing Record 5 of Set 15 | caceres
# Processing Record 6 of Set 15 | orocue
# Processing Record 7 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 15 | ardatov
# Processing Record 9 of Set 15 | huicungo
# Processing Record 10 of Set 15 | mombetsu
# Processing Record 11 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 15 | la asuncion
# Processing Record 13 of Set 15 | aljezur
# Processing Record 14 of Set 15 | portpatrick
# City not found. Skipping...
# Processing Record 15 of Set 15 | portland
# Processing Record 16 of Set 15 | deputatskiy
# Processing Record 17 of Set 15 | acapulco
# Processing Record 18 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 19 of Set 15 | wajima
# Processing Record 20 of Set 15 | luang prabang
# Processing Record 21 of Set 15 | purpe
# Processing Record 22 of Set 15 | yamada
# Processing Record 23 of Set 15 | shache
# Processing Record 24 of Set 15 | yeppoon
# Processing Record 25 of Set 15 | dunda
# Processing Record 26 of Set 15 | mayskiy
# Processing Record 27 of Set 15 | beyneu
# Processing Record 28 of Set 15 | saint-michel-des-saints
# Processing Record 29 of Set 15 | hamilton
# Processing Record 30 of Set 15 | gadsden
# Processing Record 31 of Set 15 | kirakira
# Processing Record 32 of Set 15 | maragogi
# Processing Record 33 of Set 15 | ilulissat
# Processing Record 34 of Set 15 | moose factory
# Processing Record 35 of Set 15 | krivyanskaya
# Processing Record 36 of Set 15 | great yarmouth
# Processing Record 37 of Set 15 | kamina
# Processing Record 38 of Set 15 | pointe michel
# Processing Record 39 of Set 15 | mayo
# Processing Record 40 of Set 15 | mecca
# Processing Record 41 of Set 15 | emporia
# Processing Record 42 of Set 15 | chunoyar
# Processing Record 43 of Set 15 | north myrtle beach
# Processing Record 44 of Set 15 | sibolga
# Processing Record 45 of Set 15 | shinshiro
# Processing Record 46 of Set 15 | belmonte
# Processing Record 47 of Set 15 | duluth
# Processing Record 48 of Set 15 | ferrol
# Processing Record 49 of Set 15 | shatrovo
# Processing Record 50 of Set 15 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 16 | viedma
# Processing Record 2 of Set 16 | ulladulla
# Processing Record 3 of Set 16 | sabla
# Processing Record 4 of Set 16 | semnan
# Processing Record 5 of Set 16 | neuquen
# Processing Record 6 of Set 16 | gort
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFrame.
city_data_df=pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Sechura      PE  -5.5569  -80.8222     75.16        63          93
# 1       Rong Kwang      TH  18.3390  100.3174     79.45        84         100
# 2     Puerto Ayora      EC  -0.7393  -90.3518     74.25        83          62
# 3   Port Elizabeth      ZA -33.9180   25.5701     61.09        72           0
# 4        Jamestown      US  42.0970  -79.2353     60.44        25           0
# 5       Georgetown      MY   5.4112  100.3354     82.33        92          20
# 6          Kavieng      PG  -2.5744  150.7967     83.73        69          93
# 7        Pemangkat      ID   1.1667  108.9667     78.51        85         100
# 8  Bambous Virieux      MU -20.3428   57.7575     77.25        83          40
# 9           Darnah      LY  32.7670   22.6367     62.98        64          53
#
#    Wind Speed Current Description
# 0       17.98     overcast clouds
# 1        1.86     overcast clouds
# 2        7.40       broken clouds
# 3       10.36           clear sky
# 4        8.05           clear sky
# 5        2.30          few clouds
# 6        1.50     overcast clouds
# 7        4.03     overcast clouds
# 8        6.91    scattered clouds
# 9        8.59       broken clouds

# %%
# Create the output file (CSV).
output_data_file= "Weather_Database/WeatherPy_Database.csv"
# Export the DataFrame as a CSV file.
city_data_df.to_csv(output_data_file, index_label="City_ID")
